# %%
from IPython.display import display, HTML
import spot
spot.setup(size='5,4')

# %% [markdown]
# This shows the effect of running `cleanup_acceptance()` on 10 randomly generated automata.

# %%
txt = "<TABLE><TR><TH>before</TH><TH>after</TH>"
for a in spot.automata('randaut -A "random 4" -H -Q5 -n10 2|'):
    txt += "<TR><TD>{0}</TD><TD>{1}</TD></TR>".format(a.show('.a').data, spot.cleanup_acceptance(a).show('.a').data)
txt += ("</TABLE>")
HTML(txt)
# Out:
# <TABLE><TR><TH>before</TH><TH>after</TH><TR><TD><svg height="89pt" viewBox="0.00 0.00 360.00 88.80" width="360pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.602007 0.602007) rotate(0) translate(4 143.512)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-143.512 594,-143.512 594,4 -4,4" stroke="none"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="179" y="-125.312">Fin(</text>
# <text fill="#ff4da0" font-family="Lato" font-size="14.00" text-anchor="start" x="204" y="-125.312">❶</text>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="220" y="-125.312">) | (Fin(</text>
# <text fill="#ff7f00" font-family="Lato" font-size="14.00" text-anchor="start" x="263" y="-125.312">❷</text>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="279" y="-125.312">) &amp; Fin(</text>
# <text fill="#6a3d9a" font-family="Lato" font-size="14.00" text-anchor="start" x="325" y="-125.312">❸</text>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="341" y="-125.312">) &amp; Fin(</text>
# <text fill="#1f78b4" font-family="Lato" font-size="14.00" text-anchor="start" x="387" y="-125.312">⓿</text>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="403" y="-125.312">))</text>
# <!-- I -->
# <!-- 0 -->
# <g class="node" id="node2"><title>0</title>
# <ellipse cx="56" cy="-37.5121" fill="#ffffaa" rx="18" ry="18" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="middle" x="56" y="-33.8121">0</text>
# </g>
# <!-- I&#45;&gt;0 -->
# <g class="edge" id="edge1"><title>I-&gt;0</title>
# <path d="M1.15491,-37.5121C2.79388,-37.5121 17.1543,-37.5121 30.6317,-37.5121" fill="none" stroke="black"/>
# <polygon fill="black" points="37.9419,-37.5121 30.9419,-40.6622 34.4419,-37.5122 30.9419,-37.5122 30.9419,-37.5122 30.9419,-37.5122 34.4419,-37.5122 30.9418,-34.3622 37.9419,-37.5121 37.9419,-37.5121" stroke="black"/>
# </g>
# <!-- 4 -->
# <g class="node" id="node3"><title>4</title>
# <ellipse cx="183" cy="-50.5121" fill="#ffffaa" rx="18" ry="18" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="middle" x="183" y="-46.8121">4</text>
# </g>
# <!-- 0&#45;&gt;4 -->
# <g class="edge" id="edge2"><title>0-&gt;4</title>
# <path d="M68.596,-50.651C74.8444,-56.7283 83.0916,-63.301 92,-66.5121 114.996,-74.8013 123.115,-71.7127 147,-66.5121 151.456,-65.542 156.023,-63.9519 160.326,-62.1414" fill="none" stroke="black"/>
# <polygon fill="black" points="166.816,-59.1723 161.761,-64.9489 163.634,-60.6284 160.451,-62.0844 160.451,-62.0844 160.451,-62.0844 163.634,-60.6284 159.14,-59.2199 166.816,-59.1723 166.816,-59.1723" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="92" y="-75.3121">!p0 &amp; p1</text>
# </g>
# <!-- 4&#45;&gt;0 -->
# <g class="edge" id="edge8"><title>4-&gt;0</title>
# <path d="M166.816,-41.852C160.839,-38.9082 153.789,-35.9904 147,-34.5121 125.079,-29.7392 99.4546,-31.2598 81.1662,-33.518" fill="none" stroke="black"/>
# <polygon fill="black" points="73.8097,-34.5148 80.3233,-30.4534 77.278,-34.0448 80.7463,-33.5749 80.7463,-33.5749 80.7463,-33.5749 77.278,-34.0448 81.1693,-36.6963 73.8097,-34.5148 73.8097,-34.5148" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="92" y="-52.3121">!p0 &amp; p1</text>
# <text fill="#1f78b4" font-family="Lato" font-size="14.00" text-anchor="start" x="103.5" y="-38.3121">⓿</text>
# <text fill="#ff7f00" font-family="Lato" font-size="14.00" text-anchor="start" x="119.5" y="-38.3121">❷</text>
# </g>
# <!-- 4&#45;&gt;4 -->
# <g class="edge" id="edge9"><title>4-&gt;4</title>
# <path d="M172.627,-65.3038C169.249,-75.9286 172.707,-86.5121 183,-86.5121 190.881,-86.5121 194.754,-80.3083 194.622,-72.6319" fill="none" stroke="black"/>
# <polygon fill="black" points="193.373,-65.3038 197.654,-71.6754 193.961,-68.7541 194.549,-72.2044 194.549,-72.2044 194.549,-72.2044 193.961,-68.7541 191.444,-72.7334 193.373,-65.3038 193.373,-65.3038" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="155.5" y="-90.3121">!p0 &amp; p1</text>
# </g>
# <!-- 3 -->
# <g class="node" id="node6"><title>3</title>
# <ellipse cx="314" cy="-50.5121" fill="#ffffaa" rx="18" ry="18" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="middle" x="314" y="-46.8121">3</text>
# </g>
# <!-- 4&#45;&gt;3 -->
# <g class="edge" id="edge10"><title>4-&gt;3</title>
# <path d="M201.13,-50.5121C223.587,-50.5121 263.116,-50.5121 288.67,-50.5121" fill="none" stroke="black"/>
# <polygon fill="black" points="295.799,-50.5121 288.799,-53.6622 292.299,-50.5122 288.799,-50.5122 288.799,-50.5122 288.799,-50.5122 292.299,-50.5122 288.799,-47.3622 295.799,-50.5121 295.799,-50.5121" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="219" y="-54.3121">!p0 &amp; !p1</text>
# </g>
# <!-- 1 -->
# <g class="node" id="node4"><title>1</title>
# <ellipse cx="445" cy="-23.5121" fill="#ffffaa" rx="18" ry="18" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="middle" x="445" y="-19.8121">1</text>
# </g>
# <!-- 1&#45;&gt;0 -->
# <g class="edge" id="edge3"><title>1-&gt;0</title>
# <path d="M426.693,-23.2652C382.883,-22.6937 264.034,-21.4781 165,-23.5121 132.535,-24.1789 123.988,-20.9291 92,-26.5121 88.0784,-27.1966 83.9855,-28.2025 80.0386,-29.3321" fill="none" stroke="black"/>
# <polygon fill="black" points="73.1606,-31.4562 78.9194,-26.3808 76.5048,-30.4234 79.8489,-29.3906 79.8489,-29.3906 79.8489,-29.3906 76.5048,-30.4234 80.7785,-32.4003 73.1606,-31.4562 73.1606,-31.4562" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="222.5" y="-26.3121">p0 &amp; p1</text>
# </g>
# <!-- 2 -->
# <g class="node" id="node5"><title>2</title>
# <ellipse cx="572" cy="-23.5121" fill="#ffffaa" rx="18" ry="18" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="middle" x="572" y="-19.8121">2</text>
# </g>
# <!-- 1&#45;&gt;2 -->
# <g class="edge" id="edge4"><title>1-&gt;2</title>
# <path d="M463.119,-23.5121C484.691,-23.5121 521.912,-23.5121 546.495,-23.5121" fill="none" stroke="black"/>
# <polygon fill="black" points="553.687,-23.5121 546.687,-26.6622 550.187,-23.5122 546.687,-23.5122 546.687,-23.5122 546.687,-23.5122 550.187,-23.5122 546.687,-20.3622 553.687,-23.5121 553.687,-23.5121" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="481" y="-41.3121">p0 &amp; !p1</text>
# <text fill="#1f78b4" font-family="Lato" font-size="14.00" text-anchor="start" x="492.5" y="-27.3121">⓿</text>
# <text fill="#6a3d9a" font-family="Lato" font-size="14.00" text-anchor="start" x="508.5" y="-27.3121">❸</text>
# </g>
# <!-- 2&#45;&gt;1 -->
# <g class="edge" id="edge5"><title>2-&gt;1</title>
# <path d="M556.689,-13.6464C550.598,-10.0187 543.237,-6.34991 536,-4.51213 512.307,1.50404 504.693,1.50404 481,-4.51213 476.137,-5.74689 471.219,-7.80818 466.668,-10.1282" fill="none" stroke="black"/>
# <polygon fill="black" points="460.311,-13.6464 464.91,-7.50062 463.374,-11.9515 466.436,-10.2567 466.436,-10.2567 466.436,-10.2567 463.374,-11.9515 467.961,-13.0127 460.311,-13.6464 460.311,-13.6464" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="481" y="-8.31213">!p0 &amp; p1</text>
# </g>
# <!-- 3&#45;&gt;1 -->
# <g class="edge" id="edge7"><title>3-&gt;1</title>
# <path d="M331.864,-46.9824C354.366,-42.2727 394.343,-33.9054 419.987,-28.5381" fill="none" stroke="black"/>
# <polygon fill="black" points="427.131,-27.0428 420.925,-31.5601 423.706,-27.7598 420.28,-28.4769 420.28,-28.4769 420.28,-28.4769 423.706,-27.7598 419.634,-25.3937 427.131,-27.0428 427.131,-27.0428" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="350" y="-46.3121">!p0 &amp; !p1</text>
# </g>
# <!-- 3&#45;&gt;3 -->
# <g class="edge" id="edge6"><title>3-&gt;3</title>
# <path d="M303.292,-65.3038C299.806,-75.9286 303.375,-86.5121 314,-86.5121 322.135,-86.5121 326.134,-80.3083 325.997,-72.6319" fill="none" stroke="black"/>
# <polygon fill="bl
